# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.DataFrame(np.arange(0,20).reshape(5,4),index=['Row1','Row2','Row3','Row4','Row5'],columns=['Col1','Col2','Col3','Col4'])
my_df
# Out:
#       Col1  Col2  Col3  Col4
# Row1     0     1     2     3
# Row2     4     5     6     7
# Row3     8     9    10    11
# Row4    12    13    14    15
# Row5    16    17    18    19

# %%
my_df.to_excel('Test.xlsx')

# %%
my_df.loc['Row1']
# Out:
# Col1    0
# Col2    1
# Col3    2
# Col4    3
# Name: Row1, dtype: int32

# %%
my_df.loc['Row2']
# Out:
# Col1    4
# Col2    5
# Col3    6
# Col4    7
# Name: Row2, dtype: int32

# %%
my_df.iloc[0:3,0:2]
# Out:
#       Col1  Col2
# Row1     0     1
# Row2     4     5
# Row3     8     9

# %%
# Convert Dataframe to Array

my_df.iloc[:,:].values.shape
# Out:
# (5, 4)

# %%
my_df[['Col1','Col2']]
# Out:
#       Col1  Col2
# Row1     0     1
# Row2     4     5
# Row3     8     9
# Row4    12    13
# Row5    16    17

# %%
my_df.loc['Row1']
# Out:
# Col1    0
# Col2    1
# Col3    2
# Col4    3
# Name: Row1, dtype: int32

# %%
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

# %%
df_country_code = pd.read_html(url, match='IMDb Rating', header=0)

# %%
df_country_code[0]
# Out:
#      Unnamed: 0                                       Rank & Title  \
# 0           NaN               1.  The Shawshank Redemption  (1994)
# 1           NaN                          2.  The Godfather  (1972)
# 2           NaN                 3.  The Godfather: Part II  (1974)
# 3           NaN                        4.  The Dark Knight  (2008)
# 4           NaN                           5.  12 Angry Men  (1957)
# 5           NaN                       6.  Schindler's List  (1993)
# 6           NaN  7.  The Lord of the Rings: The Return of the K...
# 7           NaN                           8.  Pulp Fiction  (1994)
# 8           NaN        9.  Il buono, il brutto, il cattivo  (1966)
# 9           NaN  10.  The Lord of the Rings: The Fellowship of ...
# 10          NaN                            11.  Fight Club  (1999)
# 11          NaN                          12.  Forrest Gump  (1994)
# 12          NaN                             13.  Inception  (2010)
# ...

# %%
imdb_movies = df_country_code[0]

# %%
type(imdb_movies)
# Out:
# pandas.core.frame.DataFrame

# %%
imdb_movies1=imdb_movies.iloc[:,1:3]

# %%
imdb_movies1
# Out:
#                                           Rank & Title  IMDb Rating
# 0                 1.  The Shawshank Redemption  (1994)          9.2
# 1                            2.  The Godfather  (1972)          9.1
# 2                   3.  The Godfather: Part II  (1974)          9.0
# 3                          4.  The Dark Knight  (2008)          9.0
# 4                             5.  12 Angry Men  (1957)          8.9
# 5                         6.  Schindler's List  (1993)          8.9
# 6    7.  The Lord of the Rings: The Return of the K...          8.9
# 7                             8.  Pulp Fiction  (1994)          8.8
# 8          9.  Il buono, il brutto, il cattivo  (1966)          8.8
# 9    10.  The Lord of the Rings: The Fellowship of ...          8.8
# 10                             11.  Fight Club  (1999)          8.8
# 11                           12.  Forrest Gump  (1994)          8.8
# 12                              13.  Inception  (2010)          8.7
# ...

# %%
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...
